# %%
# !pip install psycopg2

# %%
import psycopg2

# %%
try: 
    conn = psycopg2.connect("host=127.0.0.1 dbname=postgres user=postgres password=aSHISH@1234")
except psycopg2.Error as e: 
    print("Error: Could not make connection to the Postgres database")
    print(e)

# %%
try: 
    cur = conn.cursor()
except psycopg2.Error as e: 
    print("Error: Could not get curser to the Database")
    print(e)

# %%
conn.set_session(autocommit=True)

# %%
try: 
    cur.execute("create database firstdb")
except psycopg2.Error as e:
    print(e)
# Out:
# database "firstdb" already exists

# %%
try: 
    conn.close()
except psycopg2.Error as e:
    print(e)
    
try: 
    conn = psycopg2.connect("host=127.0.0.1 dbname=myfirstdb user=postgres password=aSHISH@1234")
except psycopg2.Error as e: 
    print("Error: Could not make connection to the Postgres database")
    print(e)
    
try: 
    cur = conn.cursor()
except psycopg2.Error as e: 
    print("Error: Could not get curser to the Database")
    print(e)

conn.set_session(autocommit=True)

# %%
try: 
    cur.execute("CREATE TABLE IF NOT EXISTS students (student_id int, name varchar,\
    age int, gender varchar, subject varchar, marks int);")
except psycopg2.Error as e: 
    print("Error: Issue creating table")
    print (e)

# %%
try: 
    cur.execute("INSERT INTO students (student_id, name, age, gender, subject, marks) \
                 VALUES (%s, %s, %s, %s, %s, %s)", \
                 (1, "xyz", 23, "FeMale", "Python", 85))
except psycopg2.Error as e: 
    print("Error: Inserting Rows")
    print (e)
    
try: 
    cur.execute("INSERT INTO students (student_id, name, age, gender, subject, marks) \
                  VALUES (%s, %s, %s, %s, %s, %s)",
                  ( 2, "Ashish", 22, "male", "Python", 86))
except psycopg2.Error as e: 
    print("Error: Inserting Rows")
    print (e)

# %%
try: 
    cur.execute("SELECT * FROM students;")
except psycopg2.Error as e: 
    print("Error: select *")
    print (e)

row = cur.fetchone()
while row:
    print(row)
    row = cur.fetchone()
# Out:
# (1, 'xyz', 23, 'FeMale', 'Python', 85)
# (2, 'Ashish', 22, 'male', 'Python', 86)

# %%
cur.close()
conn.close()

# %%
import pandas as pd

# %%
AccountsCountry=pd.read_csv("Downloads/Wealth-AccountSeries.csv")

# %%
AccountsCountry.head()
# Out:
#              Code                                     Indicator Name  \
# 0       NW.HCA.TO                  Human capital (constant 2018 US$)
# 1       NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2  NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3  NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4  NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
#
#                                      Long definition  \
# 0  Human capital is computed as the present value...
# 1  Human capital is computed as the present value...
# 2  Human capital is computed as the present value...
# 3  Human capital is computed as the present value...
# 4  Human capital is computed as the present value...
#
#                                               Source          Topic  \
# 0  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 1  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# ...

# %%
AccountsCountry=pd.read_csv("Downloads/Wealth-AccountSeries.csv")

# %%
AccountsCountry.head()
# Out:
#              Code                                     Indicator Name  \
# 0       NW.HCA.TO                  Human capital (constant 2018 US$)
# 1       NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2  NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3  NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4  NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
#
#                                      Long definition  \
# 0  Human capital is computed as the present value...
# 1  Human capital is computed as the present value...
# 2  Human capital is computed as the present value...
# 3  Human capital is computed as the present value...
# 4  Human capital is computed as the present value...
#
#                                               Source          Topic  \
# 0  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 1  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# ...

# %%
AccountsCountry_clean = AccountsCountry[['Source',	'Topic',	'Unit of measure',	'Periodicity']]

# %%
AccountsCountry_clean.head()
# Out:
#                                               Source          Topic  \
# 0  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 1  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 2  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 3  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 4  World Bank. 2021. The Changing Wealth of Natio...  Human capital
#
#      Unit of measure Periodicity
# 0  Constant 2018 US$      Annual
# 1  Constant 2018 US$      Annual
# 2  Constant 2018 US$      Annual
# 3  Constant 2018 US$      Annual
# 4  Constant 2018 US$      Annual

# %%
AccountsCountry_clean.head()
# Out:
#                                               Source          Topic  \
# 0  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 1  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 2  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 3  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 4  World Bank. 2021. The Changing Wealth of Natio...  Human capital
#
#      Unit of measure Periodicity
# 0  Constant 2018 US$      Annual
# 1  Constant 2018 US$      Annual
# 2  Constant 2018 US$      Annual
# 3  Constant 2018 US$      Annual
# 4  Constant 2018 US$      Annual

# %%
AccountsCountr=pd.read_csv("Downloads/Wealth-AccountData.csv")

# %%
AccountsCountr.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995] 1996 [YR1996] 1997 [YR1997] 1998 [YR1998] 1999 [YR1999]  \
# 0      4.49E+10      4.34E+10      3.71E+10      3.88E+10      4.22E+10
# 1      14072.79      13708.99       11794.1      12399.48      13573.26
# 2      3468.858      3355.549      2868.997      3013.391      3259.893
# 3      6507.931      6353.737      5466.692      5901.072       6492.73
# ...

# %%
AccountsCountr_clean=AccountsCountr[['Country Name',	'Country Code',	'Series Name',	'Series Code',	'1995 [YR1995]']]

# %%
AccountsCountr_clean.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995]
# 0      4.49E+10
# 1      14072.79
# 2      3468.858
# 3      6507.931
# 4      4893.006

# %%
AccountsCountr_clean.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1995 [YR1995]'],
#       dtype='object')

# %%
AccountsCountr=AccountsCountr.drop(['1995 [YR1995]'], axis=1)

# %%
AccountsCountr.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1996 [YR1996] 1997 [YR1997] 1998 [YR1998] 1999 [YR1999] 2000 [YR2000]  \
# 0      4.34E+10      3.71E+10      3.88E+10      4.22E+10      4.36E+10
# 1      13708.99       11794.1      12399.48      13573.26      14118.13
# 2      3355.549      2868.997      3013.391      3259.893      3424.007
# 3      6353.737      5466.692      5901.072       6492.73      6872.019
# ...

# %%
Accountsdata=pd.read_csv("Downloads/Wealth-AccountData.csv")

# %%
Accountsdata.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995] 1996 [YR1996] 1997 [YR1997] 1998 [YR1998] 1999 [YR1999]  \
# 0      4.49E+10      4.34E+10      3.71E+10      3.88E+10      4.22E+10
# 1      14072.79      13708.99       11794.1      12399.48      13573.26
# 2      3468.858      3355.549      2868.997      3013.391      3259.893
# 3      6507.931      6353.737      5466.692      5901.072       6492.73
# ...

# %%
Accountsdata_clean=Accountsdata[['Country Name',	'Country Code',	'Series Name'	,'Series Code']]

# %%
Accountsdata_clean.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC

# %%
Accountsdata_clean.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC

# %%
def create_database():
    conn=psycopg2.connect("host=127.0.0.1 dbname=postgres user=postgres password=aSHISH@1234")
    conn.set_session(autocommit=True)
    cur = conn.cursor()
    cur.execute("DROP DATABASE IF EXISTS account")
    cur.execute("CREATE DATABASE account")
    conn.close()
    conn=psycopg2.connect("host=127.0.0.1 dbname=account user=postgres password=aSHISH@1234")
    cur = conn.cursor()
    return cur,conn

# %%
def drop_tables(cur,conn):
    for query in drop_tables_queries:
        cur.execute(query)
        con.commit()

# %%
cur,conn= create_database()

# %%
songplay_table_create=("""CREATE TABLE IF NOT EXISTS accountscountry(
Source VARCHAR PRIMARY KEY,
Topic VARCHAR,
Periodicity VARCHAR
)""")

# %%
cur.execute(songplay_table_create)
conn.commit()
